# %% [markdown]
# Importing Lib

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from scipy.stats import skew

# %% [markdown]
# Reading Data

# %%
df= pd.read_csv('AirIndia (Domestic).csv')

# %% [markdown]
# Head of data

# %%
df.head()
# Out:
#   Month  DEPARTURES\n  HOURS\n  KILOMETER\n(TH)  PASSENGERS CARRIED\n  \
# 0   APR        8331.0  13998.0           7670.0              852743.0
# 1   MAY        8648.0  14547.0           8039.0              933573.0
# 2  JUNE        8279.0  14232.0           7367.0              809681.0
# 3  JULY        8562.0  14860.0           7725.0              803943.0
# 4   AUG        8547.0  14666.0           7756.0              908224.0
#
#    PASSENGER KMS. PERFORMED\n(TH)  AVAILABLE SEAT KILOMETRE\n(TH)  \
# 0                        862694.0                       1219041.0
# 1                        948498.0                       1277627.0
# 2                        830542.0                       1170875.0
# 3                        822897.0                       1227813.0
# 4                        911328.0                       1232691.0
#
#     PAX. LOAD FACTOR#\n(IN %)    FY
# 0                        70.8  FY14
# 1                        74.2  FY14
# 2                        70.9  FY14
# 3                        67.0  FY14
# 4                        73.9  FY14

# %% [markdown]
# INFO

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Month                          120 non-null    object
#  1   DEPARTURES
#                     119 non-null    float64
#  2   HOURS
#                          119 non-null    float64
#  3   KILOMETER
# (TH)                 119 non-null    float64
#  4   PASSENGERS CARRIED
#             119 non-null    float64
#  5   PASSENGER KMS. PERFORMED
# (TH)  119 non-null    float64
#  6   AVAILABLE SEAT KILOMETRE
# (TH)  119 non-null    float64
#  7    PAX. LOAD FACTOR#
# (IN %)      119 non-null    float64
#  8   FY                             120 non-null    object
# dtypes: float64(7), object(2)
# memory usage: 8.6+ KB

# %% [markdown]
# Checking Null Values

# %%
df.isnull().sum()
# Out:
# Month                             0
# DEPARTURES\n                      1
# HOURS\n                           1
# KILOMETER\n(TH)                   1
# PASSENGERS CARRIED\n              1
# PASSENGER KMS. PERFORMED\n(TH)    1
# AVAILABLE SEAT KILOMETRE\n(TH)    1
#  PAX. LOAD FACTOR#\n(IN %)        1
# FY                                0
# dtype: int64

# %% [markdown]
# Replacing Null Values with ( 0 )

# %%
df.fillna(0,inplace=True)

# %% [markdown]
# If there is any Null values left after replacing null values with 0

# %%
df.isnull().sum()
# Out:
# Month                             0
# DEPARTURES\n                      0
# HOURS\n                           0
# KILOMETER\n(TH)                   0
# PASSENGERS CARRIED\n              0
# PASSENGER KMS. PERFORMED\n(TH)    0
# AVAILABLE SEAT KILOMETRE\n(TH)    0
#  PAX. LOAD FACTOR#\n(IN %)        0
# FY                                0
# dtype: int64

# %% [markdown]
# Pair plot to view linear relation between values

# %%
sns.pairplot(data=df)

# %% [markdown]
# Shape

# %%
df.shape
# Out:
# (120, 9)

# %% [markdown]
# Correlation between Values

# %%
df.corr()
# Out:
#                                 DEPARTURES\n   HOURS\n  KILOMETER\n(TH)  \
# DEPARTURES\n                        1.000000  0.984001         0.940587
# HOURS\n                             0.984001  1.000000         0.956881
# KILOMETER\n(TH)                     0.940587  0.956881         1.000000
# PASSENGERS CARRIED\n                0.949309  0.959424         0.933369
# PASSENGER KMS. PERFORMED\n(TH)      0.945246  0.963022         0.934921
# AVAILABLE SEAT KILOMETRE\n(TH)      0.984041  0.992216         0.963640
#  PAX. LOAD FACTOR#\n(IN %)          0.779095  0.792806         0.780902
#
#                                 PASSENGERS CARRIED\n  \
# DEPARTURES\n                                0.949309
# HOURS\n                                     0.959424
# KILOMETER\n(TH)                             0.933369
# PASSENGERS CARRIED\n                        1.000000
# PASSENGER KMS. PERFORMED\n(TH)              0.994207
# AVAILABLE SEAT KILOMETRE\n(TH)              0.959613
#  PAX. LOAD FACTOR#\n(IN %)                  0.823344
#
#                                 PASSENGER KMS. PERFORMED\n(TH)  \
# DEPARTURES\n                                          0.945246
# HOURS\n                                               0.963022
# KILOMETER\n(TH)                                       0.934921
# PASSENGERS CARRIED\n                                  0.994207
# PASSENGER KMS. PERFORMED\n(TH)                        1.000000
# AVAILABLE SEAT KILOMETRE\n(TH)                        0.966703
#  PAX. LOAD FACTOR#\n(IN %)                            0.847906
#
#                                 AVAILABLE SEAT KILOMETRE\n(TH)  \
# DEPARTURES\n                                          0.984041
# HOURS\n                                               0.992216
# KILOMETER\n(TH)                                       0.963640
# PASSENGERS CARRIED\n                                  0.959613
# PASSENGER KMS. PERFORMED\n(TH)                        0.966703
# AVAILABLE SEAT KILOMETRE\n(TH)                        1.000000
#  PAX. LOAD FACTOR#\n(IN %)                            0.803512
#
#                                  PAX. LOAD FACTOR#\n(IN %)
# DEPARTURES\n                                      0.779095
# HOURS\n                                           0.792806
# KILOMETER\n(TH)                                   0.780902
# PASSENGERS CARRIED\n                              0.823344
# PASSENGER KMS. PERFORMED\n(TH)                    0.847906
# AVAILABLE SEAT KILOMETRE\n(TH)                    0.803512
#  PAX. LOAD FACTOR#\n(IN %)                        1.000000

# %% [markdown]
# Columns

# %%
df.columns
# Out:
# Index(['Month', 'DEPARTURES\n', 'HOURS\n', 'KILOMETER\n(TH)',
#        'PASSENGERS CARRIED\n', 'PASSENGER KMS. PERFORMED\n(TH)',
#        'AVAILABLE SEAT KILOMETRE\n(TH)', ' PAX. LOAD FACTOR#\n(IN %)', 'FY'],
#       dtype='object')

# %% [markdown]
# Change columns name

# %%
df.rename(columns = {'DEPARTURES\n':'DEPARTURES'}, inplace = True)
df.rename(columns = {'HOURS\n':'HOURS'}, inplace = True)
df.rename(columns = {'KILOMETER\n(TH)':'KILOMETER_TH'}, inplace = True)
df.rename(columns = {'PASSENGERS CARRIED\n':'PASSENGERS_CARRIED'}, inplace = True)
df.rename(columns = {'AVAILABLE SEAT KILOMETRE\n(TH)':'AVAILABLE_SEAT_KILOMETRE_TH'}, inplace = True)
df.rename(columns = {' PAX. LOAD FACTOR#\n(IN %)':' PAX_LOAD FACTOR_ %'}, inplace = True)
df.rename(columns = {'Month':'MONTHS'}, inplace = True)
df.rename(columns = {'PASSENGER KMS. PERFORMED\n(TH)':'MONTHPASSENGER_KMS_PERFORMED_TH'}, inplace = True)
df.head()
# Out:
#   MONTHS  DEPARTURES    HOURS  KILOMETER_TH  PASSENGERS_CARRIED  \
# 0    APR      8331.0  13998.0        7670.0            852743.0
# 1    MAY      8648.0  14547.0        8039.0            933573.0
# 2   JUNE      8279.0  14232.0        7367.0            809681.0
# 3   JULY      8562.0  14860.0        7725.0            803943.0
# 4    AUG      8547.0  14666.0        7756.0            908224.0
#
#    MONTHPASSENGER_KMS_PERFORMED_TH  AVAILABLE_SEAT_KILOMETRE_TH  \
# 0                         862694.0                    1219041.0
# 1                         948498.0                    1277627.0
# 2                         830542.0                    1170875.0
# 3                         822897.0                    1227813.0
# 4                         911328.0                    1232691.0
#
#     PAX_LOAD FACTOR_ %    FY
# 0                 70.8  FY14
# 1                 74.2  FY14
# 2                 70.9  FY14
# 3                 67.0  FY14
# 4                 73.9  FY14

# %% [markdown]
# Cat_cols , Num_cols

# %%
cat_cols = df.columns[df.dtypes == object] 
num_cols = df.select_dtypes(include=np.number).columns.tolist()
print("The categorical columns are", cat_cols)
print("The numerical columns are", num_cols)
# Out:
# The categorical columns are Index(['MONTHS', 'FY'], dtype='object')
# The numerical columns are ['DEPARTURES', 'HOURS', 'KILOMETER_TH', 'PASSENGERS_CARRIED', 'MONTHPASSENGER_KMS_PERFORMED_TH', 'AVAILABLE_SEAT_KILOMETRE_TH', ' PAX_LOAD FACTOR_ %']

# %% [markdown]
# EDA

# %%
for col in df.select_dtypes(include=np.number).columns.tolist():
    print(col)
    plt.figure(figsize = (15, 4))
    plt.subplot(1, 2, 1)
    sns.distplot(a=df[col], bins=20, color='green',
             hist_kws={"edgecolor": 'black'})
    plt.ylabel('count')
    plt.subplot(1, 2, 2)
    sns.boxplot(x=df[col], color='pink')
    plt.show()
# Out:
# DEPARTURES
# HOURS
# KILOMETER_TH
# PASSENGERS_CARRIED
# MONTHPASSENGER_KMS_PERFORMED_TH
# AVAILABLE_SEAT_KILOMETRE_TH
#  PAX_LOAD FACTOR_ %

# %%
df[df['DEPARTURES']<100]
# Out:
#     MONTHS  DEPARTURES  HOURS  KILOMETER_TH  PASSENGERS_CARRIED  \
# 84     APR         0.0    0.0           0.0                 0.0
# 119    MAR         0.0    0.0           0.0                 0.0
#
#      MONTHPASSENGER_KMS_PERFORMED_TH  AVAILABLE_SEAT_KILOMETRE_TH  \
# 84                               0.0                          0.0
# 119                              0.0                          0.0
#
#       PAX_LOAD FACTOR_ %    FY
# 84                   0.0  FY21
# 119                  0.0  FY23

# %%
corr = df.corr()
sns.heatmap(corr, cmap="Blues", annot=True)
# Out:
# <AxesSubplot:>
